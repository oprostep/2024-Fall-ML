# %% [markdown]
# <a href="https://colab.research.google.com/github/oprostep/2024-Fall-ML/blob/main/202104591_%EA%B9%80%ED%95%98%EC%A4%80_Transformer_pt_to_en_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #202104591 김하준
#
# Version issue로 1번과 2번 코드가 전부 호환이 되지 않아, 같은 데이터를 사용하여 유사한 Transformer를 구현한 소스를 Github에서 구해 실행했습니다.
#
# https://github.com/MohsenEbadpour/Neural-Machine-Translation-using-Transformers-on-Portuguese-to-English-/blob/main/source%208%20head%20-%204%20layer%20(main)%20.ipynb

# %%
#tensorflow_text 버전 다운그레이드
#!pip install -U tensorflow
# !pip install tensorflow_text==2.15.0
# Out:
# Collecting tensorflow_text==2.15.0
#   Downloading tensorflow_text-2.15.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.9 kB)
# Requirement already satisfied: tensorflow-hub>=0.13.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow_text==2.15.0) (0.16.1)
# Collecting tensorflow<2.16,>=2.15.0 (from tensorflow_text==2.15.0)
#   Downloading tensorflow-2.15.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.2 kB)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15.0->tensorflow_text==2.15.0) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15.0->tensorflow_text==2.15.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15.0->tensorflow_text==2.15.0) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15.0->tensorflow_text==2.15.0) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15.0->tensorflow_text==2.15.0) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15.0->tensorflow_text==2.15.0) (3.12.1)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15.0->tensorflow_text==2.15.0) (18.1.1)
# Collecting ml-dtypes~=0.3.1 (from tensorflow<2.16,>=2.15.0->tensorflow_text==2.15.0)
#   Downloading ml_dtypes-0.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15.0->tensorflow_text==2.15.0) (1.26.4)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15.0->tensorflow_text==2.15.0) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15.0->tensorflow_text==2.15.0) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15.0->tensorflow_text==2.15.0) (4.25.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15.0->tensorflow_text==2.15.0) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15.0->tensorflow_text==2.15.0) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15.0->tensorflow_text==2.15.0) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15.0->tensorflow_text==2.15.0) (4.12.2)
# Collecting wrapt<1.15,>=1.11.0 (from tensorflow<2.16,>=2.15.0->tensorflow_text==2.15.0)
#   Downloading wrapt-1.14.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15.0->tensorflow_text==2.15.0) (0.37.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15.0->tensorflow_text==2.15.0) (1.68.1)
# Collecting tensorboard<2.16,>=2.15 (from tensorflow<2.16,>=2.15.0->tensorflow_text==2.15.0)
#   Downloading tensorboard-2.15.2-py3-none-any.whl.metadata (1.7 kB)
# Collecting tensorflow-estimator<2.16,>=2.15.0 (from tensorflow<2.16,>=2.15.0->tensorflow_text==2.15.0)
#   Downloading tensorflow_estimator-2.15.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Collecting keras<2.16,>=2.15.0 (from tensorflow<2.16,>=2.15.0->tensorflow_text==2.15.0)
#   Downloading keras-2.15.0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: tf-keras>=2.14.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow-hub>=0.13.0->tensorflow_text==2.15.0) (2.15.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow<2.16,>=2.15.0->tensorflow_text==2.15.0) (0.45.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15.0->tensorflow_text==2.15.0) (2.27.0)
# Collecting google-auth-oauthlib<2,>=0.5 (from tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15.0->tensorflow_text==2.15.0)
#   Downloading google_auth_oauthlib-1.2.1-py2.py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15.0->tensorflow_text==2.15.0) (3.7)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15.0->tensorflow_text==2.15.0) (2.32.3)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15.0->tensorflow_text==2.15.0)
#   Downloading tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl.metadata (1.1 kB)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15.0->tensorflow_text==2.15.0) (3.1.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15.0->tensorflow_text==2.15.0) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15.0->tensorflow_text==2.15.0) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15.0->tensorflow_text==2.15.0) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15.0->tensorflow_text==2.15.0) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15.0->tensorflow_text==2.15.0) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15.0->tensorflow_text==2.15.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15.0->tensorflow_text==2.15.0) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15.0->tensorflow_text==2.15.0) (2024.8.30)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15.0->tensorflow_text==2.15.0) (3.0.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15.0->tensorflow_text==2.15.0) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15.0->tensorflow_text==2.15.0) (3.2.2)
# Downloading tensorflow_text-2.15.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 63.3 MB/s eta 0:00:00
# Downloading tensorflow-2.15.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (475.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 475.2/475.2 MB 1.5 MB/s eta 0:00:00
# Downloading keras-2.15.0-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 58.6 MB/s eta 0:00:00
# Downloading ml_dtypes-0.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 65.8 MB/s eta 0:00:00
# Downloading tensorboard-2.15.2-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 73.9 MB/s eta 0:00:00
# Downloading tensorflow_estimator-2.15.0-py2.py3-none-any.whl (441 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 442.0/442.0 kB 30.5 MB/s eta 0:00:00
# Downloading wrapt-1.14.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 6.5 MB/s eta 0:00:00
# Downloading google_auth_oauthlib-1.2.1-py2.py3-none-any.whl (24 kB)
# Downloading tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl (6.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 76.4 MB/s eta 0:00:00
# Installing collected packages: wrapt, tensorflow-estimator, tensorboard-data-server, ml-dtypes, keras, google-auth-oauthlib, tensorboard, tensorflow, tensorflow_text
#   Attempting uninstall: wrapt
#     Found existing installation: wrapt 1.17.0
#     Uninstalling wrapt-1.17.0:
#       Successfully uninstalled wrapt-1.17.0
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.8.0
#     Uninstalling tensorflow-estimator-2.8.0:
#       Successfully uninstalled tensorflow-estimator-2.8.0
#   Attempting uninstall: tensorboard-data-server
#     Found existing installation: tensorboard-data-server 0.6.1
#     Uninstalling tensorboard-data-server-0.6.1:
#       Successfully uninstalled tensorboard-data-server-0.6.1
#   Attempting uninstall: ml-dtypes
#     Found existing installation: ml-dtypes 0.4.1
#     Uninstalling ml-dtypes-0.4.1:
#       Successfully uninstalled ml-dtypes-0.4.1
#   Attempting uninstall: keras
#     Found existing installation: keras 2.8.0
#     Uninstalling keras-2.8.0:
#       Successfully uninstalled keras-2.8.0
#   Attempting uninstall: google-auth-oauthlib
#     Found existing installation: google-auth-oauthlib 0.4.6
#     Uninstalling google-auth-oauthlib-0.4.6:
#       Successfully uninstalled google-auth-oauthlib-0.4.6
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.8.0
#     Uninstalling tensorboard-2.8.0:
#       Successfully uninstalled tensorboard-2.8.0
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.8.4
#     Uninstalling tensorflow-2.8.4:
#       Successfully uninstalled tensorflow-2.8.4
#   Attempting uninstall: tensorflow_text
#     Found existing installation: tensorflow-text 2.8.2
#     Uninstalling tensorflow-text-2.8.2:
#       Successfully uninstalled tensorflow-text-2.8.2
# Successfully installed google-auth-oauthlib-1.2.1 keras-2.15.0 ml-dtypes-0.3.2 tensorboard-2.15.2 tensorboard-data-server-0.7.2 tensorflow-2.15.1 tensorflow-estimator-2.15.0 tensorflow_text-2.15.0 wrapt-1.14.1

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow_datasets as tfds
import time
import logging
import time

import numpy as np
import matplotlib.pyplot as plt

import tensorflow_datasets as tfds
import tensorflow as tf
# Import tf_text to load the ops used by the tokenizer saved model
import tensorflow_text  # pylint: disable=unused-import

# %% [markdown]
# # Loading dataset and preprocess

# %% [markdown]
# ### Loading dataset

# %%
split = ['train[:5%]', 'test','validation']
examples, metadata = tfds.load('ted_hrlr_translate/pt_to_en', with_info=True,
                               as_supervised=True)

train_examples, val_examples, test_examples = examples['train'], examples['validation'], examples['test']
# Out:
# Downloading and preparing dataset 124.94 MiB (download: 124.94 MiB, generated: Unknown size, total: 124.94 MiB) to /root/tensorflow_datasets/ted_hrlr_translate/pt_to_en/1.0.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Generating splits...:   0%|          | 0/3 [00:00<?, ? splits/s]
# Generating train examples...:   0%|          | 0/51785 [00:00<?, ? examples/s]
# Shuffling /root/tensorflow_datasets/ted_hrlr_translate/pt_to_en/incomplete.W7SFSU_1.0.0/ted_hrlr_translate-tra…
# Generating validation examples...:   0%|          | 0/1193 [00:00<?, ? examples/s]
# Shuffling /root/tensorflow_datasets/ted_hrlr_translate/pt_to_en/incomplete.W7SFSU_1.0.0/ted_hrlr_translate-val…
# Generating test examples...:   0%|          | 0/1803 [00:00<?, ? examples/s]
# Shuffling /root/tensorflow_datasets/ted_hrlr_translate/pt_to_en/incomplete.W7SFSU_1.0.0/ted_hrlr_translate-tes…
# Dataset ted_hrlr_translate downloaded and prepared to /root/tensorflow_datasets/ted_hrlr_translate/pt_to_en/1.0.0. Subsequent calls will reuse this data.

# %% [markdown]
# ### Loading tokenizers

# %%
model_name = 'ted_hrlr_translate_pt_en_converter'
tf.keras.utils.get_file(f'{model_name}.zip', f'https://storage.googleapis.com/download.tensorflow.org/models/{model_name}.zip',cache_dir='.', cache_subdir='', extract=True)
tokenizers = tf.saved_model.load(model_name)
# Out:
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/models/ted_hrlr_translate_pt_en_converter.zip
# 184801/184801 [==============================] - 0s 0us/step

# %%
sns.set_style("darkgrid")
plt.rcParams["figure.figsize"] = (8, 6)

lengths = []
for pt_examples, en_examples in train_examples.batch(1024):
  pt_tokens = tokenizers.en.tokenize(pt_examples)
  lengths.append(pt_tokens.row_lengths())

  en_tokens = tokenizers.en.tokenize(en_examples)
  lengths.append(en_tokens.row_lengths())
  all_lengths = np.concatenate(lengths)

plt.hist(all_lengths, np.linspace(0, 500, 101))
plt.ylim(plt.ylim())
max_length = max(all_lengths)
plt.plot([max_length, max_length], plt.ylim(),color="red")
plt.title(f'Max tokens per example: {max_length}')
plt.ylabel("#Frequency")
plt.xlabel("Count of token in Sequence")
plt.show()

# %% [markdown]
# ### Global static variables for batching

# %%
MAX_TOKENS = 128 ### based on above chart
BUFFER_SIZE = 20000
BATCH_SIZE = 128

# %% [markdown]
# ### Batching dataset

# %%
def filter_max_tokens(pt, en):
    num_tokens = tf.maximum(tf.shape(pt)[1],tf.shape(en)[1])
    return num_tokens < MAX_TOKENS

def tokenize_pairs(pt, en):
    pt = tokenizers.pt.tokenize(pt)
    pt = pt.to_tensor()
    en = tokenizers.en.tokenize(en)
    en = en.to_tensor()
    return pt, en

def generate_batches(dataset):
    return (
      dataset
      .cache()
      .shuffle(BUFFER_SIZE)
      .batch(BATCH_SIZE)
      .map(tokenize_pairs, num_parallel_calls=tf.data.AUTOTUNE)
      .filter(filter_max_tokens)
      .prefetch(tf.data.AUTOTUNE))


train_batches = generate_batches(train_examples)
val_batches = generate_batches(val_examples)
test_batches = generate_batches(test_examples)

# %% [markdown]
# ### Positional embedding

# %%
def get_angles(pos, i, d_model):
    angle_rates = 1 / np.power(10000, (2 * (i//2)) / np.float32(d_model))
    return pos * angle_rates

def positional_encoding(position, d_model):
    angle_rads = get_angles(np.arange(position)[:, np.newaxis],
                          np.arange(d_model)[np.newaxis, :],
                          d_model)

    angle_rads[:, 0::2] = np.sin(angle_rads[:, 0::2])
    angle_rads[:, 1::2] = np.cos(angle_rads[:, 1::2])
    pos_encoding = angle_rads[np.newaxis, ...]

    return tf.cast(pos_encoding, dtype=tf.float32)

# %% [markdown]
# ### Maskikng the attentions

# %%
def create_padding_mask(seq):
    seq = tf.cast(tf.math.equal(seq, 0), tf.float32)
    return seq[:, tf.newaxis, tf.newaxis, :]


def create_look_ahead_mask(size):
    mask = 1 - tf.linalg.band_part(tf.ones((size, size)), -1, 0)
    return mask

# %% [markdown]
# # Attention Implementation

# %% [markdown]
# ### Attention weights

# %%
def scaled_dot_product_attention(q, k, v, mask):
        matmul_qk = tf.matmul(q, k, transpose_b=True)


        dk = tf.cast(tf.shape(k)[-1], tf.float32)
        scaled_attention_logits = matmul_qk / tf.math.sqrt(dk)

        if mask is not None:
            scaled_attention_logits += (mask * -1e9)

        attention_weights = tf.nn.softmax(scaled_attention_logits, axis=-1)  # (..., seq_len_q, seq_len_k)

        output = tf.matmul(attention_weights, v)  # (..., seq_len_q, depth_v)

        return output, attention_weights

# %% [markdown]
# ### Multi-Head Attention

# %%
class MultiHeadAttention(tf.keras.layers.Layer):
    def __init__(self,*, d_model, num_heads):
        super(MultiHeadAttention, self).__init__()
        self.num_heads = num_heads
        self.d_model = d_model

        assert d_model % self.num_heads == 0

        self.depth = d_model // self.num_heads

        self.wq = tf.keras.layers.Dense(d_model)
        self.wk = tf.keras.layers.Dense(d_model)
        self.wv = tf.keras.layers.Dense(d_model)

        self.dense = tf.keras.layers.Dense(d_model)

    def split_heads(self, x, batch_size):
        x = tf.reshape(x, (batch_size, -1, self.num_heads, self.depth))
        return tf.transpose(x, perm=[0, 2, 1, 3])

    def call(self, v, k, q, mask):
        batch_size = tf.shape(q)[0]

        q = self.wq(q)
        k = self.wk(k)
        v = self.wv(v)

        q = self.split_heads(q, batch_size)
        k = self.split_heads(k, batch_size)
        v = self.split_heads(v, batch_size)


        scaled_attention, attention_weights = scaled_dot_product_attention(q, k, v, mask)

        scaled_attention = tf.transpose(scaled_attention, perm=[0, 2, 1, 3])

        concat_attention = tf.reshape(scaled_attention,(batch_size, -1, self.d_model))
        output = self.dense(concat_attention)

        return output, attention_weights

# %% [markdown]
# # Transformer Implementations

# %% [markdown]
# ### Feed forward network

# %%
def point_wise_feed_forward_network(d_model, dff):
    model = keras.models.Sequential()
    model.add(keras.layers.Dense(dff, activation='relu')) # (batch_size, seq_len, dff)
    model.add(tf.keras.layers.Dense(d_model)) # (batch_size, seq_len, d_model)
    return model

# %% [markdown]
# ### Encoder Implementation

# %%
class EncoderLayer(tf.keras.layers.Layer):
    def __init__(self,*, d_model, num_heads, dff, rate=0.1):
        super(EncoderLayer, self).__init__()
        self.mha = MultiHeadAttention(d_model=d_model, num_heads=num_heads)
        self.ffn = point_wise_feed_forward_network(d_model, dff)

        self.layernorm1 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
        self.layernorm2 = tf.keras.layers.LayerNormalization(epsilon=1e-6)

        self.dropout1 = tf.keras.layers.Dropout(rate)
        self.dropout2 = tf.keras.layers.Dropout(rate)

    def call(self, x, training, mask):
        attn_output, _ = self.mha(x, x, x, mask)  # (batch_size, input_seq_len, d_model)
        attn_output = self.dropout1(attn_output, training=training)
        out1 = self.layernorm1(x + attn_output)  # (batch_size, input_seq_len, d_model)

        ffn_output = self.ffn(out1)  # (batch_size, input_seq_len, d_model)
        ffn_output = self.dropout2(ffn_output, training=training)
        out2 = self.layernorm2(out1 + ffn_output)  # (batch_size, input_seq_len, d_model)
        return out2

# %%
class Encoder(tf.keras.layers.Layer):
    def __init__(self,*, num_layers, d_model, num_heads, dff, input_vocab_size,rate=0.1):
        super(Encoder, self).__init__()

        self.d_model = d_model
        self.num_layers = num_layers

        self.embedding = tf.keras.layers.Embedding(input_vocab_size, d_model)
        self.pos_encoding = positional_encoding(MAX_TOKENS, self.d_model)
        self.enc_layers = [EncoderLayer(d_model=d_model, num_heads=num_heads, dff=dff, rate=rate) for _ in range(num_layers)]

        self.dropout = tf.keras.layers.Dropout(rate)

    def call(self, x, training, mask):
        seq_len = tf.shape(x)[1]

        x = self.embedding(x)
        x *= tf.math.sqrt(tf.cast(self.d_model, tf.float32))
        x += self.pos_encoding[:, :seq_len, :]

        x = self.dropout(x, training=training)

        for i in range(self.num_layers):
            x = self.enc_layers[i](x, training, mask)

        return x

# %% [markdown]
# ### Decoder Implementation

# %%
class DecoderLayer(tf.keras.layers.Layer):
    def __init__(self,*, d_model, num_heads, dff, rate=0.1):
        super(DecoderLayer, self).__init__()
        self.mha1 = MultiHeadAttention(d_model=d_model, num_heads=num_heads)
        self.mha2 = MultiHeadAttention(d_model=d_model, num_heads=num_heads)

        self.ffn = point_wise_feed_forward_network(d_model, dff)

        self.layernorm1 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
        self.layernorm2 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
        self.layernorm3 = tf.keras.layers.LayerNormalization(epsilon=1e-6)

        self.dropout1 = tf.keras.layers.Dropout(rate)
        self.dropout2 = tf.keras.layers.Dropout(rate)
        self.dropout3 = tf.keras.layers.Dropout(rate)

    def call(self, x, enc_output, training,look_ahead_mask, padding_mask):
        # enc_output.shape == (batch_size, input_seq_len, d_model)

        attn1, attn_weights_block1 = self.mha1(x, x, x, look_ahead_mask)
        attn1 = self.dropout1(attn1, training=training)
        out1 = self.layernorm1(attn1 + x)

        attn2, attn_weights_block2 = self.mha2(enc_output, enc_output, out1, padding_mask)
        attn2 = self.dropout2(attn2, training=training)
        out2 = self.layernorm2(attn2 + out1)

        ffn_output = self.ffn(out2)
        ffn_output = self.dropout3(ffn_output, training=training)
        out3 = self.layernorm3(ffn_output + out2)

        return out3, attn_weights_block1, attn_weights_block2

# %%
class Decoder(tf.keras.layers.Layer):
    def __init__(self,*, num_layers, d_model, num_heads, dff, target_vocab_size,rate=0.1):
        super(Decoder, self).__init__()
        self.d_model = d_model
        self.num_layers = num_layers

        self.embedding = tf.keras.layers.Embedding(target_vocab_size, d_model)
        self.pos_encoding = positional_encoding(MAX_TOKENS, d_model)

        self.dec_layers = [DecoderLayer(d_model=d_model, num_heads=num_heads, dff=dff, rate=rate) for _ in range(num_layers)]
        self.dropout = tf.keras.layers.Dropout(rate)

    def call(self, x, enc_output, training,look_ahead_mask, padding_mask):
        seq_len = tf.shape(x)[1]
        attention_weights = {}

        x = self.embedding(x)  # (batch_size, target_seq_len, d_model)
        x *= tf.math.sqrt(tf.cast(self.d_model, tf.float32))
        x += self.pos_encoding[:, :seq_len, :]

        x = self.dropout(x, training=training)

        for i in range(self.num_layers):
            x, block1, block2 = self.dec_layers[i](x, enc_output, training,
                                                look_ahead_mask, padding_mask)

            attention_weights[f'decoder_layer{i+1}_block1'] = block1
            attention_weights[f'decoder_layer{i+1}_block2'] = block2

        # x.shape == (batch_size, target_seq_len, d_model)
        return x, attention_weights

# %% [markdown]
# ### Transformer Model Implementation

# %%
class Transformer(tf.keras.Model):
    def __init__(self,*, num_layers, d_model, num_heads, dff, input_vocab_size,target_vocab_size, rate=0.1):
        super().__init__()
        self.encoder = Encoder(num_layers=num_layers, d_model=d_model,num_heads=num_heads, dff=dff,input_vocab_size=input_vocab_size, rate=rate)
        self.decoder = Decoder(num_layers=num_layers, d_model=d_model,num_heads=num_heads, dff=dff,target_vocab_size=target_vocab_size, rate=rate)
        self.final_layer = tf.keras.layers.Dense(target_vocab_size)

    def call(self, inputs, training):
        inp, tar = inputs
        padding_mask, look_ahead_mask = self.create_masks(inp, tar)
        enc_output = self.encoder(inp, training, padding_mask)

        dec_output, attention_weights = self.decoder(tar, enc_output, training, look_ahead_mask, padding_mask)
        final_output = self.final_layer(dec_output)

        return final_output, attention_weights

    def create_masks(self, inp, tar):
        padding_mask = create_padding_mask(inp)

        look_ahead_mask = create_look_ahead_mask(tf.shape(tar)[1])
        dec_target_padding_mask = create_padding_mask(tar)
        look_ahead_mask = tf.maximum(dec_target_padding_mask, look_ahead_mask)
        return padding_mask, look_ahead_mask

# %% [markdown]
# # Build models and related functions(loss,optimizer,...) & Train

# %% [markdown]
# ### Define detail of the network architecture

# %%
num_layers = 4
d_model = 128
dff = 512
num_heads = 8
dropout_rate = 0.1
EPOCHS = 50

# %% [markdown]
# ### Optimizer Implementation
#
# step의 casting 오류가 있어 원본에서 수정

# %%
class CustomSchedule(tf.keras.optimizers.schedules.LearningRateSchedule):
    def __init__(self, d_model, warmup_steps=4000):
        super(CustomSchedule, self).__init__()

        self.d_model = d_model
        self.d_model = tf.cast(self.d_model, tf.float32)

        self.warmup_steps = warmup_steps

    def __call__(self, step):
        arg1 = tf.math.rsqrt(tf.cast(step, dtype=tf.float32))   #casting
        arg2 = tf.cast(step, dtype=tf.float32) * (self.warmup_steps ** -1.5)    #casting
        return tf.math.rsqrt(self.d_model) * tf.math.minimum(arg1, arg2)

learning_rate = CustomSchedule(d_model)
optimizer = tf.keras.optimizers.Adam(learning_rate, beta_1=0.9, beta_2=0.98, epsilon=1e-9)
temp_learning_rate_schedule = CustomSchedule(d_model)
plt.plot(temp_learning_rate_schedule(tf.range(50000, dtype=tf.float32)))
plt.title("Learning Rate Scheduler")
plt.ylabel('Learning Rate')
plt.xlabel('Train Step')
plt.show()

# %% [markdown]
# ### Loss Implementation

# %%
loss_object = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True, reduction='none')

def loss_function(real, pred):
    mask = tf.math.logical_not(tf.math.equal(real, 0))
    loss_ = loss_object(real, pred)

    mask = tf.cast(mask, dtype=loss_.dtype)
    loss_ *= mask

    return tf.reduce_sum(loss_)/tf.reduce_sum(mask)


def accuracy_function(real, pred):
    accuracies = tf.equal(real, tf.argmax(pred, axis=2))

    mask = tf.math.logical_not(tf.math.equal(real, 0))
    accuracies = tf.math.logical_and(mask, accuracies)

    accuracies = tf.cast(accuracies, dtype=tf.float32)
    mask = tf.cast(mask, dtype=tf.float32)
    return tf.reduce_sum(accuracies)/tf.reduce_sum(mask)


train_loss = tf.keras.metrics.Mean(name='train_loss')
train_accuracy = tf.keras.metrics.Mean(name='train_accuracy')

# %% [markdown]
# ### Build a transformer model

# %%
transformer = Transformer(
    num_layers=num_layers,
    d_model=d_model,
    num_heads=num_heads,
    dff=dff,
    input_vocab_size=tokenizers.pt.get_vocab_size().numpy(),
    target_vocab_size=tokenizers.en.get_vocab_size().numpy(),
    rate=dropout_rate)

# %% [markdown]
# ### Check point handler

# %%
checkpoint_path = './checkpoints/train'

ckpt = tf.train.Checkpoint(transformer=transformer,
                           optimizer=optimizer)

ckpt_manager = tf.train.CheckpointManager(ckpt, checkpoint_path, max_to_keep=5)

if ckpt_manager.latest_checkpoint:
    ckpt.restore(ckpt_manager.latest_checkpoint)
    print('Latest checkpoint restored!!')

# %% [markdown]
# ### Train on batch

# %%
train_step_signature = [
    tf.TensorSpec(shape=(None, None), dtype=tf.int64),
    tf.TensorSpec(shape=(None, None), dtype=tf.int64),
]


@tf.function(input_signature=train_step_signature)
def train_step(inp, tar):
    tar_inp = tar[:, :-1]
    tar_real = tar[:, 1:]

    with tf.GradientTape() as tape:
        predictions, _ = transformer([inp, tar_inp],training = True)
        loss = loss_function(tar_real, predictions)

    gradients = tape.gradient(loss, transformer.trainable_variables)
    optimizer.apply_gradients(zip(gradients, transformer.trainable_variables))

    train_loss(loss)
    train_accuracy(accuracy_function(tar_real, predictions))

# %% [markdown]
# ### Train loop

# %%
def train():
    losses = []
    acc = []
    for epoch in range(EPOCHS):
        start = time.time()

        train_loss.reset_states()
        train_accuracy.reset_states()
        L = 0
        A = 0
        i = 0
        for (batch, (inp, tar)) in enumerate(train_batches):
            train_step(inp, tar)

            i+=1
            L += train_loss.result()
            A += train_accuracy.result()

            if batch % 50 == 0:
                print(f'Epoch {epoch + 1} Batch {batch} Loss {train_loss.result():.4f} Accuracy {train_accuracy.result():.4f}')

        if (epoch + 1) % 5 == 0:
            ckpt_save_path = ckpt_manager.save()
            print(f'Saving checkpoint for epoch {epoch+1} at {ckpt_save_path}')

        print(f'Epoch {epoch + 1} Loss {train_loss.result():.4f} Accuracy {train_accuracy.result():.4f}')
        print(f'Time taken for 1 epoch: {time.time() - start:.2f} secs\n')

        losses.append(L/i)
        acc.append(A/i)

    return losses,acc

results = train()
# Out:
# Epoch 1 Batch 0 Loss 8.8806 Accuracy 0.0000
# Epoch 1 Batch 50 Loss 8.8287 Accuracy 0.0040
# Epoch 1 Batch 100 Loss 8.7218 Accuracy 0.0244
# Epoch 1 Batch 150 Loss 8.6024 Accuracy 0.0324
# Epoch 1 Batch 200 Loss 8.4533 Accuracy 0.0369
# Epoch 1 Batch 250 Loss 8.2750 Accuracy 0.0415
# Epoch 1 Loss 8.0885 Accuracy 0.0488
# Time taken for 1 epoch: 122.10 secs
#
# Epoch 2 Batch 0 Loss 6.7688 Accuracy 0.1131
# Epoch 2 Batch 50 Loss 6.6676 Accuracy 0.1170
# Epoch 2 Batch 100 Loss 6.5118 Accuracy 0.1203
# Epoch 2 Batch 150 Loss 6.3950 Accuracy 0.1247
# Epoch 2 Batch 200 Loss 6.2907 Accuracy 0.1324
# Epoch 2 Batch 250 Loss 6.1959 Accuracy 0.1412
# Epoch 2 Batch 300 Loss 6.1016 Accuracy 0.1487
# Epoch 2 Loss 6.1016 Accuracy 0.1487
# Time taken for 1 epoch: 67.96 secs
#
# Epoch 3 Batch 0 Loss 5.5869 Accuracy 0.1853
# Epoch 3 Batch 50 Loss 5.4777 Accuracy 0.1930
# Epoch 3 Batch 100 Loss 5.4154 Accuracy 0.1978
# Epoch 3 Batch 150 Loss 5.3578 Accuracy 0.2029
# Epoch 3 Batch 200 Loss 5.3142 Accuracy 0.2067
# Epoch 3 Batch 250 Loss 5.2740 Accuracy 0.2106
# Epoch 3 Batch 300 Loss 5.2362 Accuracy 0.2144
# Epoch 3 Loss 5.2322 Accuracy 0.2148
# Time taken for 1 epoch: 82.37 secs
#
# Epoch 4 Batch 0 Loss 4.9661 Accuracy 0.2405
# Epoch 4 Batch 50 Loss 4.9723 Accuracy 0.2402
# Epoch 4 Batch 100 Loss 4.9535 Accuracy 0.2417
# Epoch 4 Batch 150 Loss 4.9199 Accuracy 0.2447
# Epoch 4 Batch 200 Loss 4.8916 Accuracy 0.2470
# Epoch 4 Batch 250 Loss 4.8696 Accuracy 0.2495
# Epoch 4 Batch 300 Loss 4.8446 Accuracy 0.2516
# Epoch 4 Loss 4.8432 Accuracy 0.2518
# Time taken for 1 epoch: 67.15 secs
#
# Epoch 5 Batch 0 Loss 4.7986 Accuracy 0.2543
# Epoch 5 Batch 50 Loss 4.6755 Accuracy 0.2652
# Epoch 5 Batch 100 Loss 4.6461 Accuracy 0.2689
# Epoch 5 Batch 150 Loss 4.6277 Accuracy 0.2705
# Epoch 5 Batch 200 Loss 4.6096 Accuracy 0.2722
# Epoch 5 Batch 250 Loss 4.5901 Accuracy 0.2736
# Epoch 5 Batch 300 Loss 4.5750 Accuracy 0.2754
# Saving checkpoint for epoch 5 at ./checkpoints/train/ckpt-1
# Epoch 5 Loss 4.5736 Accuracy 0.2755
# Time taken for 1 epoch: 67.57 secs
#
# Epoch 6 Batch 0 Loss 4.3699 Accuracy 0.2942
# Epoch 6 Batch 50 Loss 4.4280 Accuracy 0.2894
# Epoch 6 Batch 100 Loss 4.3901 Accuracy 0.2938
# Epoch 6 Batch 150 Loss 4.3670 Accuracy 0.2969
# Epoch 6 Batch 200 Loss 4.3449 Accuracy 0.2996
# Epoch 6 Batch 250 Loss 4.3252 Accuracy 0.3020
# Epoch 6 Batch 300 Loss 4.3062 Accuracy 0.3042
# Epoch 6 Loss 4.3062 Accuracy 0.3042
# Time taken for 1 epoch: 63.90 secs
#
# Epoch 7 Batch 0 Loss 4.0858 Accuracy 0.3133
# Epoch 7 Batch 50 Loss 4.0833 Accuracy 0.3304
# Epoch 7 Batch 100 Loss 4.0722 Accuracy 0.3316
# Epoch 7 Batch 150 Loss 4.0520 Accuracy 0.3346
# Epoch 7 Batch 200 Loss 4.0249 Accuracy 0.3379
# Epoch 7 Batch 250 Loss 3.9982 Accuracy 0.3408
# Epoch 7 Loss 3.9767 Accuracy 0.3434
# Time taken for 1 epoch: 63.46 secs
#
# Epoch 8 Batch 0 Loss 3.9030 Accuracy 0.3469
# Epoch 8 Batch 50 Loss 3.7275 Accuracy 0.3718
# Epoch 8 Batch 100 Loss 3.7190 Accuracy 0.3738
# Epoch 8 Batch 150 Loss 3.7081 Accuracy 0.3747
# Epoch 8 Batch 200 Loss 3.6896 Accuracy 0.3774
# Epoch 8 Batch 250 Loss 3.6766 Accuracy 0.3793
# Epoch 8 Loss 3.6540 Accuracy 0.3823
# Time taken for 1 epoch: 62.67 secs
#
# Epoch 9 Batch 0 Loss 3.4330 Accuracy 0.4034
# Epoch 9 Batch 50 Loss 3.4372 Accuracy 0.4068
# Epoch 9 Batch 100 Loss 3.4252 Accuracy 0.4092
# Epoch 9 Batch 150 Loss 3.4194 Accuracy 0.4099
# Epoch 9 Batch 200 Loss 3.4017 Accuracy 0.4125
# Epoch 9 Batch 250 Loss 3.3864 Accuracy 0.4143
# Epoch 9 Batch 300 Loss 3.3763 Accuracy 0.4155
# Epoch 9 Loss 3.3743 Accuracy 0.4158
# Time taken for 1 epoch: 65.37 secs
#
# Epoch 10 Batch 0 Loss 3.1349 Accuracy 0.4545
# Epoch 10 Batch 50 Loss 3.1812 Accuracy 0.4363
# Epoch 10 Batch 100 Loss 3.1553 Accuracy 0.4406
# Epoch 10 Batch 150 Loss 3.1506 Accuracy 0.4417
# Epoch 10 Batch 200 Loss 3.1444 Accuracy 0.4423
# Epoch 10 Batch 250 Loss 3.1346 Accuracy 0.4440
# Epoch 10 Batch 300 Loss 3.1295 Accuracy 0.4446
# Saving checkpoint for epoch 10 at ./checkpoints/train/ckpt-2
# Epoch 10 Loss 3.1276 Accuracy 0.4449
# Time taken for 1 epoch: 65.56 secs
#
# Epoch 11 Batch 0 Loss 2.9609 Accuracy 0.4746
# Epoch 11 Batch 50 Loss 2.9535 Accuracy 0.4661
# Epoch 11 Batch 100 Loss 2.9436 Accuracy 0.4659
# Epoch 11 Batch 150 Loss 2.9349 Accuracy 0.4670
# Epoch 11 Batch 200 Loss 2.9227 Accuracy 0.4690
# Epoch 11 Batch 250 Loss 2.9177 Accuracy 0.4700
# Epoch 11 Loss 2.9087 Accuracy 0.4715
# Time taken for 1 epoch: 64.85 secs
#
# Epoch 12 Batch 0 Loss 2.6499 Accuracy 0.5142
# Epoch 12 Batch 50 Loss 2.7209 Accuracy 0.4950
# Epoch 12 Batch 100 Loss 2.7406 Accuracy 0.4926
# Epoch 12 Batch 150 Loss 2.7448 Accuracy 0.4921
# Epoch 12 Batch 200 Loss 2.7312 Accuracy 0.4941
# Epoch 12 Batch 250 Loss 2.7286 Accuracy 0.4948
# Epoch 12 Batch 300 Loss 2.7236 Accuracy 0.4955
# Epoch 12 Loss 2.7236 Accuracy 0.4956
# Time taken for 1 epoch: 62.36 secs
#
# Epoch 13 Batch 0 Loss 2.5593 Accuracy 0.5242
# Epoch 13 Batch 50 Loss 2.5725 Accuracy 0.5148
# Epoch 13 Batch 100 Loss 2.5714 Accuracy 0.5147
# Epoch 13 Batch 150 Loss 2.5765 Accuracy 0.5148
# Epoch 13 Batch 200 Loss 2.5781 Accuracy 0.5145
# Epoch 13 Batch 250 Loss 2.5764 Accuracy 0.5146
# Epoch 13 Batch 300 Loss 2.5749 Accuracy 0.5151
# Epoch 13 Loss 2.5749 Accuracy 0.5151
# Time taken for 1 epoch: 63.21 secs
#
# Epoch 14 Batch 0 Loss 2.3670 Accuracy 0.5353
# Epoch 14 Batch 50 Loss 2.4297 Accuracy 0.5343
# Epoch 14 Batch 100 Loss 2.4413 Accuracy 0.5318
# Epoch 14 Batch 150 Loss 2.4460 Accuracy 0.5313
# Epoch 14 Batch 200 Loss 2.4407 Accuracy 0.5324
# Epoch 14 Batch 250 Loss 2.4400 Accuracy 0.5329
# Epoch 14 Batch 300 Loss 2.4409 Accuracy 0.5327
# Epoch 14 Loss 2.4400 Accuracy 0.5328
# Time taken for 1 epoch: 63.17 secs
#
# Epoch 15 Batch 0 Loss 2.4282 Accuracy 0.5225
# Epoch 15 Batch 50 Loss 2.2918 Accuracy 0.5526
# Epoch 15 Batch 100 Loss 2.2945 Accuracy 0.5527
# Epoch 15 Batch 150 Loss 2.2937 Accuracy 0.5520
# Epoch 15 Batch 200 Loss 2.3009 Accuracy 0.5511
# Epoch 15 Batch 250 Loss 2.3047 Accuracy 0.5508
# Epoch 15 Batch 300 Loss 2.3059 Accuracy 0.5509
# Saving checkpoint for epoch 15 at ./checkpoints/train/ckpt-3
# Epoch 15 Loss 2.3055 Accuracy 0.5510
# Time taken for 1 epoch: 64.64 secs
#
# Epoch 16 Batch 0 Loss 2.1066 Accuracy 0.5675
# Epoch 16 Batch 50 Loss 2.1632 Accuracy 0.5680
# Epoch 16 Batch 100 Loss 2.1684 Accuracy 0.5680
# Epoch 16 Batch 150 Loss 2.1695 Accuracy 0.5679
# Epoch 16 Batch 200 Loss 2.1739 Accuracy 0.5679
# Epoch 16 Batch 250 Loss 2.1766 Accuracy 0.5679
# Epoch 16 Batch 300 Loss 2.1787 Accuracy 0.5679
# Epoch 16 Loss 2.1783 Accuracy 0.5680
# Time taken for 1 epoch: 63.97 secs
#
# Epoch 17 Batch 0 Loss 2.0442 Accuracy 0.5893
# Epoch 17 Batch 50 Loss 2.0289 Accuracy 0.5876
# Epoch 17 Batch 100 Loss 2.0431 Accuracy 0.5865
# Epoch 17 Batch 150 Loss 2.0536 Accuracy 0.5856
# Epoch 17 Batch 200 Loss 2.0609 Accuracy 0.5845
# Epoch 17 Batch 250 Loss 2.0683 Accuracy 0.5831
# Epoch 17 Batch 300 Loss 2.0730 Accuracy 0.5828
# Epoch 17 Loss 2.0737 Accuracy 0.5827
# Time taken for 1 epoch: 82.25 secs
#
# Epoch 18 Batch 0 Loss 1.9184 Accuracy 0.6070
# Epoch 18 Batch 50 Loss 1.9621 Accuracy 0.5983
# Epoch 18 Batch 100 Loss 1.9628 Accuracy 0.5975
# Epoch 18 Batch 150 Loss 1.9712 Accuracy 0.5964
# Epoch 18 Batch 200 Loss 1.9758 Accuracy 0.5960
# Epoch 18 Batch 250 Loss 1.9807 Accuracy 0.5955
# Epoch 18 Batch 300 Loss 1.9855 Accuracy 0.5952
# Epoch 18 Loss 1.9857 Accuracy 0.5952
# Time taken for 1 epoch: 64.19 secs
#
# Epoch 19 Batch 0 Loss 1.7709 Accuracy 0.6327
# Epoch 19 Batch 50 Loss 1.8733 Accuracy 0.6118
# Epoch 19 Batch 100 Loss 1.8886 Accuracy 0.6094
# Epoch 19 Batch 150 Loss 1.8956 Accuracy 0.6085
# Epoch 19 Batch 200 Loss 1.9006 Accuracy 0.6074
# Epoch 19 Batch 250 Loss 1.9040 Accuracy 0.6069
# Epoch 19 Batch 300 Loss 1.9062 Accuracy 0.6067
# Epoch 19 Loss 1.9064 Accuracy 0.6067
# Time taken for 1 epoch: 64.34 secs
#
# Epoch 20 Batch 0 Loss 1.8646 Accuracy 0.6181
# Epoch 20 Batch 50 Loss 1.7816 Accuracy 0.6267
# Epoch 20 Batch 100 Loss 1.8040 Accuracy 0.6232
# Epoch 20 Batch 150 Loss 1.8154 Accuracy 0.6208
# Epoch 20 Batch 200 Loss 1.8218 Accuracy 0.6196
# Epoch 20 Batch 250 Loss 1.8250 Accuracy 0.6194
# Epoch 20 Batch 300 Loss 1.8314 Accuracy 0.6183
# Saving checkpoint for epoch 20 at ./checkpoints/train/ckpt-4
# Epoch 20 Loss 1.8312 Accuracy 0.6184
# Time taken for 1 epoch: 65.44 secs
#
# Epoch 21 Batch 0 Loss 1.7826 Accuracy 0.6222
# Epoch 21 Batch 50 Loss 1.7171 Accuracy 0.6349
# Epoch 21 Batch 100 Loss 1.7300 Accuracy 0.6330
# Epoch 21 Batch 150 Loss 1.7442 Accuracy 0.6312
# Epoch 21 Batch 200 Loss 1.7487 Accuracy 0.6307
# Epoch 21 Batch 250 Loss 1.7605 Accuracy 0.6288
# Epoch 21 Batch 300 Loss 1.7711 Accuracy 0.6270
# Epoch 21 Loss 1.7729 Accuracy 0.6267
# Time taken for 1 epoch: 65.50 secs
#
# Epoch 22 Batch 0 Loss 1.6932 Accuracy 0.6372
# Epoch 22 Batch 50 Loss 1.6642 Accuracy 0.6436
# Epoch 22 Batch 100 Loss 1.6786 Accuracy 0.6407
# Epoch 22 Batch 150 Loss 1.6956 Accuracy 0.6376
# Epoch 22 Batch 200 Loss 1.6979 Accuracy 0.6372
# Epoch 22 Batch 250 Loss 1.7036 Accuracy 0.6366
# Epoch 22 Batch 300 Loss 1.7130 Accuracy 0.6353
# Epoch 22 Loss 1.7143 Accuracy 0.6351
# Time taken for 1 epoch: 63.68 secs
#
# Epoch 23 Batch 0 Loss 1.6508 Accuracy 0.6481
# Epoch 23 Batch 50 Loss 1.6175 Accuracy 0.6509
# Epoch 23 Batch 100 Loss 1.6286 Accuracy 0.6492
# Epoch 23 Batch 150 Loss 1.6380 Accuracy 0.6469
# Epoch 23 Batch 200 Loss 1.6441 Accuracy 0.6463
# Epoch 23 Batch 250 Loss 1.6508 Accuracy 0.6455
# Epoch 23 Batch 300 Loss 1.6596 Accuracy 0.6443
# Epoch 23 Loss 1.6609 Accuracy 0.6441
# Time taken for 1 epoch: 64.19 secs
#
# Epoch 24 Batch 0 Loss 1.4924 Accuracy 0.6704
# Epoch 24 Batch 50 Loss 1.5732 Accuracy 0.6574
# Epoch 24 Batch 100 Loss 1.5858 Accuracy 0.6556
# Epoch 24 Batch 150 Loss 1.5952 Accuracy 0.6537
# Epoch 24 Batch 200 Loss 1.6024 Accuracy 0.6520
# Epoch 24 Batch 250 Loss 1.6102 Accuracy 0.6510
# Epoch 24 Batch 300 Loss 1.6172 Accuracy 0.6502
# Epoch 24 Loss 1.6176 Accuracy 0.6501
# Time taken for 1 epoch: 63.66 secs
#
# Epoch 25 Batch 0 Loss 1.4572 Accuracy 0.6675
# Epoch 25 Batch 50 Loss 1.5147 Accuracy 0.6651
# Epoch 25 Batch 100 Loss 1.5403 Accuracy 0.6610
# Epoch 25 Batch 150 Loss 1.5490 Accuracy 0.6597
# Epoch 25 Batch 200 Loss 1.5589 Accuracy 0.6585
# Epoch 25 Batch 250 Loss 1.5638 Accuracy 0.6579
# Epoch 25 Batch 300 Loss 1.5714 Accuracy 0.6570
# Saving checkpoint for epoch 25 at ./checkpoints/train/ckpt-5
# Epoch 25 Loss 1.5714 Accuracy 0.6570
# Time taken for 1 epoch: 65.18 secs
#
# Epoch 26 Batch 0 Loss 1.4162 Accuracy 0.6797
# Epoch 26 Batch 50 Loss 1.4954 Accuracy 0.6700
# Epoch 26 Batch 100 Loss 1.4987 Accuracy 0.6693
# Epoch 26 Batch 150 Loss 1.5111 Accuracy 0.6670
# Epoch 26 Batch 200 Loss 1.5224 Accuracy 0.6651
# Epoch 26 Batch 250 Loss 1.5278 Accuracy 0.6642
# Epoch 26 Loss 1.5318 Accuracy 0.6637
# Time taken for 1 epoch: 62.44 secs
#
# Epoch 27 Batch 0 Loss 1.4173 Accuracy 0.6863
# Epoch 27 Batch 50 Loss 1.4577 Accuracy 0.6757
# Epoch 27 Batch 100 Loss 1.4673 Accuracy 0.6737
# Epoch 27 Batch 150 Loss 1.4673 Accuracy 0.6739
# Epoch 27 Batch 200 Loss 1.4792 Accuracy 0.6719
# Epoch 27 Batch 250 Loss 1.4845 Accuracy 0.6708
# Epoch 27 Batch 300 Loss 1.4943 Accuracy 0.6694
# Epoch 27 Loss 1.4946 Accuracy 0.6694
# Time taken for 1 epoch: 62.62 secs
#
# Epoch 28 Batch 0 Loss 1.4409 Accuracy 0.6814
# Epoch 28 Batch 50 Loss 1.4106 Accuracy 0.6826
# Epoch 28 Batch 100 Loss 1.4225 Accuracy 0.6812
# Epoch 28 Batch 150 Loss 1.4301 Accuracy 0.6805
# Epoch 28 Batch 200 Loss 1.4403 Accuracy 0.6786
# Epoch 28 Batch 250 Loss 1.4502 Accuracy 0.6767
# Epoch 28 Batch 300 Loss 1.4626 Accuracy 0.6745
# Epoch 28 Loss 1.4625 Accuracy 0.6745
# Time taken for 1 epoch: 82.25 secs
#
# Epoch 29 Batch 0 Loss 1.5468 Accuracy 0.6558
# Epoch 29 Batch 50 Loss 1.3861 Accuracy 0.6870
# Epoch 29 Batch 100 Loss 1.3859 Accuracy 0.6872
# Epoch 29 Batch 150 Loss 1.3949 Accuracy 0.6852
# Epoch 29 Batch 200 Loss 1.4076 Accuracy 0.6834
# Epoch 29 Batch 250 Loss 1.4165 Accuracy 0.6820
# Epoch 29 Batch 300 Loss 1.4237 Accuracy 0.6805
# Epoch 29 Loss 1.4239 Accuracy 0.6805
# Time taken for 1 epoch: 63.46 secs
#
# Epoch 30 Batch 0 Loss 1.3710 Accuracy 0.6982
# Epoch 30 Batch 50 Loss 1.3467 Accuracy 0.6942
# Epoch 30 Batch 100 Loss 1.3630 Accuracy 0.6902
# Epoch 30 Batch 150 Loss 1.3736 Accuracy 0.6885
# Epoch 30 Batch 200 Loss 1.3827 Accuracy 0.6873
# Epoch 30 Batch 250 Loss 1.3880 Accuracy 0.6865
# Saving checkpoint for epoch 30 at ./checkpoints/train/ckpt-6
# Epoch 30 Loss 1.3973 Accuracy 0.6849
# Time taken for 1 epoch: 62.47 secs
#
# Epoch 31 Batch 0 Loss 1.2996 Accuracy 0.6986
# Epoch 31 Batch 50 Loss 1.3274 Accuracy 0.6964
# Epoch 31 Batch 100 Loss 1.3346 Accuracy 0.6954
# Epoch 31 Batch 150 Loss 1.3438 Accuracy 0.6937
# Epoch 31 Batch 200 Loss 1.3509 Accuracy 0.6925
# Epoch 31 Batch 250 Loss 1.3587 Accuracy 0.6912
# Epoch 31 Batch 300 Loss 1.3691 Accuracy 0.6898
# Epoch 31 Loss 1.3694 Accuracy 0.6898
# Time taken for 1 epoch: 63.20 secs
#
# Epoch 32 Batch 0 Loss 1.3208 Accuracy 0.6974
# Epoch 32 Batch 50 Loss 1.3016 Accuracy 0.7015
# Epoch 32 Batch 100 Loss 1.3009 Accuracy 0.7015
# Epoch 32 Batch 150 Loss 1.3184 Accuracy 0.6978
# Epoch 32 Batch 200 Loss 1.3264 Accuracy 0.6964
# Epoch 32 Batch 250 Loss 1.3352 Accuracy 0.6948
# Epoch 32 Batch 300 Loss 1.3427 Accuracy 0.6938
# Epoch 32 Loss 1.3427 Accuracy 0.6938
# Time taken for 1 epoch: 62.84 secs
#
# Epoch 33 Batch 0 Loss 1.2763 Accuracy 0.7104
# Epoch 33 Batch 50 Loss 1.2737 Accuracy 0.7056
# Epoch 33 Batch 100 Loss 1.2846 Accuracy 0.7035
# Epoch 33 Batch 150 Loss 1.2928 Accuracy 0.7022
# Epoch 33 Batch 200 Loss 1.3035 Accuracy 0.7000
# Epoch 33 Batch 250 Loss 1.3130 Accuracy 0.6983
# Epoch 33 Batch 300 Loss 1.3212 Accuracy 0.6970
# Epoch 33 Loss 1.3214 Accuracy 0.6970
# Time taken for 1 epoch: 82.25 secs
#
# Epoch 34 Batch 0 Loss 1.1820 Accuracy 0.7163
# Epoch 34 Batch 50 Loss 1.2517 Accuracy 0.7086
# Epoch 34 Batch 100 Loss 1.2593 Accuracy 0.7074
# Epoch 34 Batch 150 Loss 1.2711 Accuracy 0.7053
# Epoch 34 Batch 200 Loss 1.2809 Accuracy 0.7038
# Epoch 34 Batch 250 Loss 1.2885 Accuracy 0.7025
# Epoch 34 Batch 300 Loss 1.2968 Accuracy 0.7011
# Epoch 34 Loss 1.2982 Accuracy 0.7008
# Time taken for 1 epoch: 64.54 secs
#
# Epoch 35 Batch 0 Loss 1.2400 Accuracy 0.7175
# Epoch 35 Batch 50 Loss 1.2078 Accuracy 0.7163
# Epoch 35 Batch 100 Loss 1.2216 Accuracy 0.7143
# Epoch 35 Batch 150 Loss 1.2366 Accuracy 0.7114
# Epoch 35 Batch 200 Loss 1.2500 Accuracy 0.7090
# Epoch 35 Batch 250 Loss 1.2638 Accuracy 0.7064
# Epoch 35 Batch 300 Loss 1.2720 Accuracy 0.7049
# Saving checkpoint for epoch 35 at ./checkpoints/train/ckpt-7
# Epoch 35 Loss 1.2729 Accuracy 0.7047
# Time taken for 1 epoch: 82.78 secs
#
# Epoch 36 Batch 0 Loss 1.2398 Accuracy 0.7066
# Epoch 36 Batch 50 Loss 1.1854 Accuracy 0.7198
# Epoch 36 Batch 100 Loss 1.2074 Accuracy 0.7160
# Epoch 36 Batch 150 Loss 1.2234 Accuracy 0.7133
# Epoch 36 Batch 200 Loss 1.2321 Accuracy 0.7119
# Epoch 36 Batch 250 Loss 1.2413 Accuracy 0.7104
# Epoch 36 Batch 300 Loss 1.2508 Accuracy 0.7088
# Epoch 36 Loss 1.2518 Accuracy 0.7086
# Time taken for 1 epoch: 64.60 secs
#
# Epoch 37 Batch 0 Loss 1.1791 Accuracy 0.7274
# Epoch 37 Batch 50 Loss 1.1818 Accuracy 0.7219
# Epoch 37 Batch 100 Loss 1.1860 Accuracy 0.7205
# Epoch 37 Batch 150 Loss 1.2024 Accuracy 0.7171
# Epoch 37 Batch 200 Loss 1.2145 Accuracy 0.7147
# Epoch 37 Batch 250 Loss 1.2220 Accuracy 0.7134
# Epoch 37 Batch 300 Loss 1.2317 Accuracy 0.7118
# Epoch 37 Loss 1.2323 Accuracy 0.7116
# Time taken for 1 epoch: 64.06 secs
#
# Epoch 38 Batch 0 Loss 1.0616 Accuracy 0.7409
# Epoch 38 Batch 50 Loss 1.1594 Accuracy 0.7247
# Epoch 38 Batch 100 Loss 1.1695 Accuracy 0.7227
# Epoch 38 Batch 150 Loss 1.1855 Accuracy 0.7202
# Epoch 38 Batch 200 Loss 1.1944 Accuracy 0.7183
# Epoch 38 Batch 250 Loss 1.2011 Accuracy 0.7170
# Epoch 38 Batch 300 Loss 1.2094 Accuracy 0.7155
# Epoch 38 Loss 1.2094 Accuracy 0.7155
# Time taken for 1 epoch: 63.41 secs
#
# Epoch 39 Batch 0 Loss 1.1565 Accuracy 0.7319
# Epoch 39 Batch 50 Loss 1.1481 Accuracy 0.7258
# Epoch 39 Batch 100 Loss 1.1592 Accuracy 0.7240
# Epoch 39 Batch 150 Loss 1.1705 Accuracy 0.7219
# Epoch 39 Batch 200 Loss 1.1791 Accuracy 0.7206
# Epoch 39 Batch 250 Loss 1.1856 Accuracy 0.7195
# Epoch 39 Batch 300 Loss 1.1936 Accuracy 0.7180
# Epoch 39 Loss 1.1940 Accuracy 0.7180
# Time taken for 1 epoch: 64.52 secs
#
# Epoch 40 Batch 0 Loss 1.1257 Accuracy 0.7384
# Epoch 40 Batch 50 Loss 1.1169 Accuracy 0.7330
# Epoch 40 Batch 100 Loss 1.1302 Accuracy 0.7300
# Epoch 40 Batch 150 Loss 1.1454 Accuracy 0.7275
# Epoch 40 Batch 200 Loss 1.1554 Accuracy 0.7253
# Epoch 40 Batch 250 Loss 1.1632 Accuracy 0.7240
# Epoch 40 Batch 300 Loss 1.1738 Accuracy 0.7220
# Saving checkpoint for epoch 40 at ./checkpoints/train/ckpt-8
# Epoch 40 Loss 1.1738 Accuracy 0.7220
# Time taken for 1 epoch: 63.15 secs
#
# Epoch 41 Batch 0 Loss 1.0672 Accuracy 0.7384
# Epoch 41 Batch 50 Loss 1.1017 Accuracy 0.7360
# Epoch 41 Batch 100 Loss 1.1140 Accuracy 0.7335
# Epoch 41 Batch 150 Loss 1.1270 Accuracy 0.7309
# Epoch 41 Batch 200 Loss 1.1417 Accuracy 0.7283
# Epoch 41 Batch 250 Loss 1.1490 Accuracy 0.7267
# Epoch 41 Batch 300 Loss 1.1576 Accuracy 0.7249
# Epoch 41 Loss 1.1592 Accuracy 0.7245
# Time taken for 1 epoch: 63.80 secs
#
# Epoch 42 Batch 0 Loss 1.0082 Accuracy 0.7576
# Epoch 42 Batch 50 Loss 1.0819 Accuracy 0.7390
# Epoch 42 Batch 100 Loss 1.0922 Accuracy 0.7363
# Epoch 42 Batch 150 Loss 1.1115 Accuracy 0.7324
# Epoch 42 Batch 200 Loss 1.1205 Accuracy 0.7307
# Epoch 42 Batch 250 Loss 1.1309 Accuracy 0.7289
# Epoch 42 Loss 1.1398 Accuracy 0.7271
# Time taken for 1 epoch: 62.64 secs
#
# Epoch 43 Batch 0 Loss 1.0695 Accuracy 0.7308
# Epoch 43 Batch 50 Loss 1.0785 Accuracy 0.7388
# Epoch 43 Batch 100 Loss 1.0823 Accuracy 0.7379
# Epoch 43 Batch 150 Loss 1.0941 Accuracy 0.7357
# Epoch 43 Batch 200 Loss 1.1048 Accuracy 0.7338
# Epoch 43 Batch 250 Loss 1.1132 Accuracy 0.7322
# Epoch 43 Loss 1.1245 Accuracy 0.7300
# Time taken for 1 epoch: 62.43 secs
#
# Epoch 44 Batch 0 Loss 0.9913 Accuracy 0.7517
# Epoch 44 Batch 50 Loss 1.0525 Accuracy 0.7445
# Epoch 44 Batch 100 Loss 1.0671 Accuracy 0.7415
# Epoch 44 Batch 150 Loss 1.0845 Accuracy 0.7379
# Epoch 44 Batch 200 Loss 1.0919 Accuracy 0.7361
# Epoch 44 Batch 250 Loss 1.0993 Accuracy 0.7348
# Epoch 44 Loss 1.1084 Accuracy 0.7331
# Time taken for 1 epoch: 62.21 secs
#
# Epoch 45 Batch 0 Loss 1.0720 Accuracy 0.7389
# Epoch 45 Batch 50 Loss 1.0424 Accuracy 0.7444
# Epoch 45 Batch 100 Loss 1.0566 Accuracy 0.7422
# Epoch 45 Batch 150 Loss 1.0675 Accuracy 0.7402
# Epoch 45 Batch 200 Loss 1.0780 Accuracy 0.7384
# Epoch 45 Batch 250 Loss 1.0870 Accuracy 0.7364
# Epoch 45 Batch 300 Loss 1.0964 Accuracy 0.7345
# Saving checkpoint for epoch 45 at ./checkpoints/train/ckpt-9
# Epoch 45 Loss 1.0971 Accuracy 0.7343
# Time taken for 1 epoch: 64.02 secs
#
# Epoch 46 Batch 0 Loss 1.0674 Accuracy 0.7482
# Epoch 46 Batch 50 Loss 1.0257 Accuracy 0.7491
# Epoch 46 Batch 100 Loss 1.0467 Accuracy 0.7447
# Epoch 46 Batch 150 Loss 1.0619 Accuracy 0.7415
# Epoch 46 Batch 200 Loss 1.0708 Accuracy 0.7397
# Epoch 46 Batch 250 Loss 1.0779 Accuracy 0.7384
# Epoch 46 Batch 300 Loss 1.0867 Accuracy 0.7366
# Epoch 46 Loss 1.0867 Accuracy 0.7366
# Time taken for 1 epoch: 63.46 secs
#
# Epoch 47 Batch 0 Loss 0.9290 Accuracy 0.7629
# Epoch 47 Batch 50 Loss 1.0178 Accuracy 0.7497
# Epoch 47 Batch 100 Loss 1.0329 Accuracy 0.7468
# Epoch 47 Batch 150 Loss 1.0391 Accuracy 0.7454
# Epoch 47 Batch 200 Loss 1.0525 Accuracy 0.7431
# Epoch 47 Batch 250 Loss 1.0601 Accuracy 0.7414
# Epoch 47 Batch 300 Loss 1.0680 Accuracy 0.7402
# Epoch 47 Loss 1.0682 Accuracy 0.7402
# Time taken for 1 epoch: 63.96 secs
#
# Epoch 48 Batch 0 Loss 1.1545 Accuracy 0.7258
# Epoch 48 Batch 50 Loss 1.0152 Accuracy 0.7509
# Epoch 48 Batch 100 Loss 1.0229 Accuracy 0.7495
# Epoch 48 Batch 150 Loss 1.0312 Accuracy 0.7478
# Epoch 48 Batch 200 Loss 1.0400 Accuracy 0.7457
# Epoch 48 Batch 250 Loss 1.0466 Accuracy 0.7444
# Epoch 48 Batch 300 Loss 1.0548 Accuracy 0.7428
# Epoch 48 Loss 1.0561 Accuracy 0.7425
# Time taken for 1 epoch: 82.36 secs
#
# Epoch 49 Batch 0 Loss 0.9161 Accuracy 0.7632
# Epoch 49 Batch 50 Loss 1.0002 Accuracy 0.7538
# Epoch 49 Batch 100 Loss 1.0101 Accuracy 0.7518
# Epoch 49 Batch 150 Loss 1.0185 Accuracy 0.7497
# Epoch 49 Batch 200 Loss 1.0293 Accuracy 0.7472
# Epoch 49 Batch 250 Loss 1.0362 Accuracy 0.7458
# Epoch 49 Batch 300 Loss 1.0462 Accuracy 0.7438
# Epoch 49 Loss 1.0467 Accuracy 0.7437
# Time taken for 1 epoch: 63.29 secs
#
# Epoch 50 Batch 0 Loss 0.9197 Accuracy 0.7759
# Epoch 50 Batch 50 Loss 0.9795 Accuracy 0.7575
# Epoch 50 Batch 100 Loss 0.9953 Accuracy 0.7535
# Epoch 50 Batch 150 Loss 1.0067 Accuracy 0.7507
# Epoch 50 Batch 200 Loss 1.0161 Accuracy 0.7491
# Epoch 50 Batch 250 Loss 1.0245 Accuracy 0.7478
# Epoch 50 Batch 300 Loss 1.0329 Accuracy 0.7463
# Saving checkpoint for epoch 50 at ./checkpoints/train/ckpt-10
# Epoch 50 Loss 1.0336 Accuracy 0.7461
# Time taken for 1 epoch: 64.78 secs

# %% [markdown]
# ### Plot training loss & acc

# %%
sns.set_style("darkgrid")
plt.rcParams["figure.figsize"] = (18,6)
plt.subplot(1,2,1)
plt.plot(results[0])
plt.xlabel("Epoch")
plt.ylabel("Loss/Sparse Categorical Cross entropy")
plt.title("Loss/Epoch | Multi-head Attention: {0}".format(num_heads))

plt.subplot(1,2,2)
plt.plot(results[1],color="green")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Loss/Prediction Accuracy | Multi-head Attention: {0}".format(num_heads))

plt.tight_layout()
plt.show()

# %% [markdown]
# # Translation

# %%
class Translator(tf.Module):
    def __init__(self, tokenizers, transformer):
        self.tokenizers = tokenizers
        self.transformer = transformer

    def __call__(self, sentence, max_length=MAX_TOKENS):
        assert isinstance(sentence, tf.Tensor)
        if len(sentence.shape) == 0:
            sentence = sentence[tf.newaxis]

        sentence = self.tokenizers.pt.tokenize(sentence).to_tensor()

        encoder_input = sentence

        start_end = self.tokenizers.en.tokenize([''])[0]
        start = start_end[0][tf.newaxis]
        end = start_end[1][tf.newaxis]

        output_array = tf.TensorArray(dtype=tf.int64, size=0, dynamic_size=True)
        output_array = output_array.write(0, start)

        for i in tf.range(max_length):
            output = tf.transpose(output_array.stack())
            predictions, _ = self.transformer([encoder_input, output], training=False)
            predictions = predictions[:, -1:, :]
            predicted_id = tf.argmax(predictions, axis=-1)
            output_array = output_array.write(i+1, predicted_id[0])

            if predicted_id == end:
                break

        output = tf.transpose(output_array.stack())
        text = tokenizers.en.detokenize(output)[0]  # shape: ()
        tokens = tokenizers.en.lookup(output)[0]
        _, attention_weights = self.transformer([encoder_input, output[:,:-1]], training=False)
        return text, tokens, attention_weights

translator = Translator(tokenizers, transformer)

# %% [markdown]
# # Attention heatmap and prediction

# %%
def print_translation(sentence, tokens, ground_truth):
    print(f'{"Input:":15s}: {sentence}')
    print(f'{"Prediction":15s}: {tokens.numpy().decode("utf-8")}')
    print(f'{"Ground truth":15s}: {ground_truth}')

# %%
sentence = """é algo que nos acontece sem o nosso consentimento ."""
ground_truth = """it 's something that happens to us without our consent ."""

translated_text, translated_tokens, attention_weights = translator(
    tf.constant(sentence))
print_translation(sentence, translated_text, ground_truth)
# Out:
# Input:         : é algo que nos acontece sem o nosso consentimento .
# Prediction     : it ' s something that happens without our consent .
# Ground truth   : it 's something that happens to us without our consent .

# %%
def plot_attention_head(in_tokens, translated_tokens, attention):
    translated_tokens = translated_tokens[1:]
    ax = plt.gca()

    ax.matshow(attention,cmap ="cool")
    ax.set_xticks(range(len(in_tokens)))
    ax.set_yticks(range(len(translated_tokens)))
    labels = [label.decode('utf-8') for label in in_tokens.numpy()]
    ax.set_xticklabels(
        labels, rotation=90)
    labels = [label.decode('utf-8') for label in translated_tokens.numpy()]
    ax.set_yticklabels(labels)

# %%
def plot_attention_weights(sentence, translated_tokens, attention_heads):
    in_tokens = tf.convert_to_tensor([sentence])
    in_tokens = tokenizers.pt.tokenize(in_tokens).to_tensor()
    in_tokens = tokenizers.pt.lookup(in_tokens)[0]
    in_tokens

    fig = plt.figure(figsize=(14, 28))

    for h, head in enumerate(attention_heads):
        ax = fig.add_subplot(num_heads//2, 2, h+1)

        plot_attention_head(in_tokens, translated_tokens, head)

        ax.set_xlabel(f'Head {h+1}')

    plt.tight_layout()
    plt.show()

sns.set_style("dark")
plot_attention_weights(sentence, translated_tokens,attention_weights['decoder_layer4_block2'][0])

# %% [markdown]
# ### Sample translation

# %%
Index = 1
for test in test_examples.take(50):
    print(f"\nTest Sample #{Index} <==========================")
    pt = test[0].numpy().decode("utf-8")
    en = test[1].numpy().decode("utf-8")
    translated_text, translated_tokens, attention_weights = translator(
        tf.constant(pt))
    print_translation(pt, translated_text, en)
    Index += 1
# Out:
# Test Sample #1 <==========================
# Input:         : depois , podem fazer-se e testar-se previsões .
# Prediction     : then you can do it and test it out .
# Ground truth   : then , predictions can be made and tested .
#
# Test Sample #2 <==========================
# Input:         : forçou a parar múltiplos laboratórios que ofereciam testes brca .
# Prediction     : it forced to stop multiple labs that offered to profit .
# Ground truth   : it had forced multiple labs that were offering brca testing to stop .
#
# Test Sample #3 <==========================
# Input:         : as formigas são um exemplo clássico ; as operárias trabalham para as rainhas e vice-versa .
# Prediction     : the foregs are an example ; the operating room is for queens of queens and visa - daes .
# Ground truth   : ants are a classic example ; workers work for queens and queens work for workers .
#
# Test Sample #4 <==========================
# Input:         : uma em cada cem crianças no mundo nascem com uma doença cardíaca .
# Prediction     : one in 100 children in the world are born with a heart disease .
# Ground truth   : one of every hundred children born worldwide has some kind of heart disease .
#
# Test Sample #5 <==========================
# Input:         : neste momento da sua vida , ela está a sofrer de sida no seu expoente máximo e tinha pneumonia .
# Prediction     : at this moment of his life , she ' s suffering from aids in her excipoly and she had pneumania .
# Ground truth   : at this point in her life , she 's suffering with full-blown aids and had pneumonia .
#
# Test Sample #6 <==========================
# Input:         : onde estão as redes económicas ?
# Prediction     : where are economic networks ?
# Ground truth   : where are economic networks ?
#
# Test Sample #7 <==========================
# Input:         : ( aplausos )
# Prediction     : ( applause )
# Ground truth   : ( applause )
#
# Test Sample #8 <==========================
# Input:         : eu usei os contentores de transporte , e também os alunos ajudaram-nos a fazer toda a mobília dos edifícios , para torná-los confortáveis​​ , dentro do orçamento do governo , mas também com a mesma a área da casa , mas muito mais confortável .
# Prediction     : i used shipping containers , and also the students helped us all the mournitures of buildings , to make them comfortable , within the government budget , but also with the same area in the house , but too comfortable .
# Ground truth   : i used the shipping container and also the students helped us to make all the building furniture to make them comfortable , within the budget of the government but also the area of the house is exactly the same , but much more comfortable .
#
# Test Sample #9 <==========================
# Input:         : e , no entanto , a ironia é que a única maneira de podermos fazer qualquer coisa nova é dar um passo nessa direção .
# Prediction     : and yet the irony is that the only way that we can do something new is to take that direction .
# Ground truth   : and yet , the irony is , the only way we can ever do anything new is to step into that space .
#
# Test Sample #10 <==========================
# Input:         : a luz nunca desaparece .
# Prediction     : light never vanish .
# Ground truth   : the light never goes out .
#
# Test Sample #11 <==========================
# Input:         : `` agora , `` '' tweets '' '' , quem está a `` '' tweetar '' '' ? ''
# Prediction     : now , tweets ' s tweets , who is design ?
# Ground truth   : now , tweets , who 's tweeting ?
#
# Test Sample #12 <==========================
# Input:         : no egito , por exemplo , 91 % das mulheres que vivem hoje no egito foram mutiladas sexualmente dessa forma .
# Prediction     : in egypt , for instance , 91 percent of women who live in egypt were sexually inadequate in that way .
# Ground truth   : in egypt , for instance , 91 percent of all the females that live in egypt today have been sexually mutilated in that way .
#
# Test Sample #13 <==========================
# Input:         : por outro lado , os bebés de 15 meses ficavam a olhar para ela durante muito tempo caso ela agisse como se preferisse os brócolos , como se não percebessem a situação .
# Prediction     : on the other hand , 15 babies were just staring at it for a long time in the case of it as they preach to the brocorecolocotting , as if they did n ' t understand the situation .
# Ground truth   : on the other hand , 15 month-olds would stare at her for a long time if she acted as if she liked the broccoli , like they could n't figure this out .
#
# Test Sample #14 <==========================
# Input:         : naquele momento , percebi quanta energia negativa é precisa para conservar aquele ódio dentro de nós .
# Prediction     : at that moment , i realized how much undengative energy is it needs to look at that hate in us .
# Ground truth   : in that instant , i realized how much negative energy it takes to hold that hatred inside of you .
#
# Test Sample #15 <==========================
# Input:         : e a discussão é : o que é que isso interessa .
# Prediction     : and discussion is : what does that matter .
# Ground truth   : and the discussion is , who cares ? right ?
#
# Test Sample #16 <==========================
# Input:         : se escolhermos um lugar e formos cuidadosos , as coisas estarão sempre lá quando as procurarmos .
# Prediction     : if you choose a place and care , things will be there when you look for them .
# Ground truth   : if you designate a spot and you 're scrupulous about it , your things will always be there when you look for them .
#
# Test Sample #17 <==========================
# Input:         : é um museu muito popular agora , e criei um grande monumento para o governo .
# Prediction     : it ' s a really popular museum , and i created a great big monque to government .
# Ground truth   : it 's a very popular museum now , and i created a big monument for the government .
#
# Test Sample #18 <==========================
# Input:         : é completamente irrelevante .
# Prediction     : it ' s completely unrevering .
# Ground truth   : it 's completely irrelevant .
#
# Test Sample #19 <==========================
# Input:         : todos defenderam que a sua técnica era a melhor , mas nenhum deles tinha a certeza disso e admitiram-no .
# Prediction     : they all believed that their technique was the best era , but none of them were sure sure of it and they prevented it .
# Ground truth   : `` they all argued that , `` '' my technique is the best , '' '' but none of them actually knew , and they admitted that . ''
#
# Test Sample #20 <==========================
# Input:         : a partir daquele momento , comecei a pensar .
# Prediction     : from that moment , i started thinking .
# Ground truth   : at that moment , i started thinking .
#
# Test Sample #21 <==========================
# Input:         : mt : portanto , aqui temos a maré baixa e aqui a maré alta e no centro temos a lua .
# Prediction     : mt : so here we have the low tide and the high tide of the rhythms here and at the center we have the moon .
# Ground truth   : mt : so over here is low tide , and over here is high tide , and in the middle is the moon .
#
# Test Sample #22 <==========================
# Input:         : então , este jogo é muito simples .
# Prediction     : so this game is very straightforward .
# Ground truth   : beau lotto : so , this game is very simple .
#
# Test Sample #23 <==========================
# Input:         : então , propus a reconstrução . angariei , recolhi fundos .
# Prediction     : so i set out to reconstruction . angiene , recolrect funded .
# Ground truth   : so i proposed to rebuild . i raised — did fundraising .
#
# Test Sample #24 <==========================
# Input:         : o que nós - betty rapacholi , minha aluna , e eu - fizemos foi dar aos bebés dois pratos de comida : um prato com brócolos crus e um com bolachas deliciosas em forma de peixinho .
# Prediction     : what gives us rapayal rachi , my albno , and i did it was giving babies two to two dishwrits : a brocory broughs composic giant , covered in parchings .
# Ground truth   : what we did — betty rapacholi , who was one of my students , and i — was actually to give the babies two bowls of food : one bowl of raw broccoli and one bowl of delicious goldfish crackers .
#
# Test Sample #25 <==========================
# Input:         : é algo que nos acontece sem o nosso consentimento .
# Prediction     : it ' s something that happens without our consent .
# Ground truth   : it 's something that happens to us without our consent .
#
# Test Sample #26 <==========================
# Input:         : ardemos de paixão .
# Prediction     : let ' s license passion .
# Ground truth   : we burn with passion .
#
# Test Sample #27 <==========================
# Input:         : `` a mutilação genital é horrível , e desconhecida pelas mulheres americanas . mas , nalguns países , em muitos países , quando uma menina nasce , muito cedo na sua vida , os seus genitais são completamente removidos por um chamado `` '' cortador '' '' que , com uma lâmina de navalha , sem recurso à esterilização , corta as partes exteriores dos genitais femininos . ''
# Prediction     : ` ` mumbertol is horrible by persuaded by african women , but in some countries , in many countries , when a girl ' s born , very early in their life , their genitters are completely removed by a charmed , called ` ` ' ' one of the spell , which a signing on the provocation of women , the devils of femaleization . ' '
# Ground truth   : genital mutilation is horrible and not known by american women , but in some countries , many countries , when a child is born that 's a girl , very soon in her life , her genitals are completely cut away by a so-called cutter who has a razor blade and , in a non-sterilized way , they remove the exterior parts of a woman 's genitalia .
#
# Test Sample #28 <==========================
# Input:         : isto significa 20 % do orçamento , do orçamento relativo a cuidados de saúde do país .
# Prediction     : this means 20 percent of the budget budget service care is born .
# Ground truth   : that 's 20 percent of the budget , of the healthcare budget of the country .
#
# Test Sample #29 <==========================
# Input:         : conheci-o num evento 46664 .
# Prediction     : i met it at a 46 -6 event .
# Ground truth   : i met him at a 46664 event .
#
# Test Sample #30 <==========================
# Input:         : deixem-me mostrar-vos o que quero dizer .
# Prediction     : let me show you what i mean .
# Ground truth   : let me show you what i mean .
#
# Test Sample #31 <==========================
# Input:         : acho que este é o problema .
# Prediction     : i think this is the problem .
# Ground truth   : i think this is a problem .
#
# Test Sample #32 <==========================
# Input:         : mt : oh , 365 , o número de dias num ano , o número de dias entre cada aniversário .
# Prediction     : mt : oh , 365 , the number of days in a year , the number of days between each anniversary .
# Ground truth   : mt : oh , 365 , the number of days in a year , the number of days between each birthday .
#
# Test Sample #33 <==========================
# Input:         : como disse peter lavine , o ser humano é um ser único habilitado com uma capacidade instintiva para curar e com o espírito intelectual para manter esta capacidade inata .
# Prediction     : as petervot , the human being is a unique habited with a unintisebility to cure and with the intellectual spirit to keep this unnadenileat .
# Ground truth   : as peter levine has said , the human animal is a unique being endowed with an instinctual capacity to heal and the intellectual spirit to harness this innate capacity .
#
# Test Sample #34 <==========================
# Input:         : o cortisol é tóxico e tolda-nos o pensamento .
# Prediction     : the blurile and to be toxic and to thought .
# Ground truth   : cortisol is toxic , and it causes cloudy thinking .
#
# Test Sample #35 <==========================
# Input:         : e às vezes , em casos mais extremos , mas não muito raros , eles costuram o orifício para que a menina possa apenas urinar ou menstruar .
# Prediction     : and sometimes , in more extreme cases , but not very rare , they ' re preferring the brain to the n ' t just urined or unarat me .
# Ground truth   : and sometimes , in more extreme cases but not very rare cases , they sew the orifice up so the girl can just urinate or menstruate .
#
# Test Sample #36 <==========================
# Input:         : há sempre vestígios — não há nenhum crime perfeito .
# Prediction     : there are always apparent — no perfect crime .
# Ground truth   : there are always traces — no such thing as a perfect crime .
#
# Test Sample #37 <==========================
# Input:         : `` `` '' vai procurá-la atrás das montanhas . ''
# Prediction     : go and search for mountains behind mountains .
# Ground truth   : go and look behind the mountains .
#
# Test Sample #38 <==========================
# Input:         : ambos , adam e oz , pouparam uma hora .
# Prediction     : both , adam , and azzzara , they ' ve saved an hour .
# Ground truth   : adam and oz both saved an hour of time .
#
# Test Sample #39 <==========================
# Input:         : claro que não ! têm que treinar 24/7 .
# Prediction     : of course , no . it has to train 24 / 7 .
# Ground truth   : of course not ! you 've got to practice 24/7 .
#
# Test Sample #40 <==========================
# Input:         : logo a seguir , encontrei outra foto minha .
# Prediction     : so i came next , i found another photo of my photo .
# Ground truth   : soon after that , i found in another picture that she had , a picture of me .
#
# Test Sample #41 <==========================
# Input:         : portanto , pensei , temos a fórmula pronta .
# Prediction     : so i thought , we ' ve got ready formula .
# Ground truth   : so i was like , okay , so we 've got the formula ready .
#
# Test Sample #42 <==========================
# Input:         : parafraseando chavez , uma vez iniciada uma mudança social , esta não pode ser revertida .
# Prediction     : to feuring key tweetion , once insisting a social change , this is not something called .
# Ground truth   : to paraphrase chavez , once social change begins , it can not be reversed .
#
# Test Sample #43 <==========================
# Input:         : neste vídeo , podemos ver como um cateter muito fino leva a bobina até ao coração .
# Prediction     : on this video , you can see how a very fether life takes bob all the heart .
# Ground truth   : in this video , we can see how a very tiny catheter takes the coil to the heart .
#
# Test Sample #44 <==========================
# Input:         : e já agora , aquele café , aquele maravilhoso café que tomaram lá em baixo , na verdade imita o efeito dos neurotransmissores dos bebés .
# Prediction     : and by the way , that ca n ' t , that wonderful coffee that they took there underneath , actually imitation the effect of the neurotransmitters .
# Ground truth   : and by the way , that coffee , that wonderful coffee you 've been drinking downstairs , actually mimics the effect of those baby neurotransmitters .
#
# Test Sample #45 <==========================
# Input:         : eles têm dinheiro e poder .
# Prediction     : they have money and power .
# Ground truth   : they have money and power .
#
# Test Sample #46 <==========================
# Input:         : eu não sou o meu pai .
# Prediction     : i ' m not my dad .
# Ground truth   : i am not my father .
#
# Test Sample #47 <==========================
# Input:         : e isso afeta-nos a todos .
# Prediction     : and that affects us all .
# Ground truth   : and that affects all of us .
#
# Test Sample #48 <==========================
# Input:         : a este respeito , para membros da sociedade , não há maior honra ou privilégio do que facilitar o processo de cura de alguém , testemunhar , de estender uma mão , de partilhar o fardo do sofrimento de alguém , e de manter a esperança da sua recuperação .
# Prediction     : this respect for societies , there are no greater honors or more likely to make the process of someone ' s healing , witnessing , to fulfill one hand , to share the burden of suffering from someone ' s suffering , and maintaining the hope of their recovery .
# Ground truth   : in this respect , for members of society , there is no greater honor or privilege than facilitating that process of healing for someone , to bear witness , to reach out a hand , to share the burden of someone 's suffering , and to hold the hope for their recovery .
#
# Test Sample #49 <==========================
# Input:         : sabemos mais do que eles ?
# Prediction     : do we know more than they ?
# Ground truth   : do we know better than them ?
#
# Test Sample #50 <==========================
# Input:         : ( risos ) parece-me que todos vocês são tocs , astrofísicos e ultramaratonistas .
# Prediction     : ( laughter ) it seems to me that you all are to be fools , extreass and ultrasound .
# Ground truth   : ( laughter ) you 're all cfo , astrophysicists , ultra-marathoners , it turns out .
